# %%
from bloqade import start, cast, load, save
import os
import matplotlib.pyplot as plt
from bokeh.io import output_notebook
from bloqade.atom_arrangement import ListOfLocations, Square
from bloqade import  piecewise_linear, cast
import numpy as np
output_notebook()

if not os.path.isdir("data"):
    os.mkdir("data")
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ed0473a4-39cd-4445-ac75-b832f45b68e4">Loading BokehJS ...</span>
#     </div>

# %%
from scipy.optimize import curve_fit
from scipy.signal import find_peaks

#Chain13 without drive
info =np.array([(2.0, 0.255), (2.0, 0.335), (2.1, 0.395), (2.1, 0.55), (2.2, 0.605), (2.2, 0.68), (2.3, 0.775), (2.3, 0.68), (2.4, 0.21), (2.4, 0.015), (2.5, 0.0), (2.5, 0.0), (2.6, 0.01), (2.6, 0.04), (2.7, 0.0), (2.7, 0.0), (2.8, 0.0), (2.8, 0.015), (2.9, 0.225), (2.9, 0.295), (3.0, 0.165), (3.0, 0.01), (3.1, 0.0), (3.1, 0.0), (3.2, 0.01), (3.2, 0.0), (3.3, 0.0), (3.3, 0.0), (3.4, 0.0), (3.4, 0.03), (3.5, 0.21), (3.5, 0.265), (3.6, 0.06), (3.6, 0.0), (3.7, 0.0), (3.7, 0.0), (3.8, 0.0), (3.8, 0.015), (3.9, 0.005), (3.9, 0.0), (4.0, 0.025), (4.0, 0.05), (4.1, 0.155), (4.1, 0.09), (4.2, 0.015), (4.2, 0.01), (4.3, 0.025), (4.3, 0.015), (4.4, 0.005), (4.4, 0.025), (4.5, 0.005), (4.5, 0.005), (4.6, 0.02), (4.6, 0.025), (4.7, 0.12), (4.7, 0.12), (4.8, 0.06), (4.8, 0.02), (4.9, 0.03), (4.9, 0.02), (5.0, 0.03), (5.0, 0.03), (5.1, 0.02), (5.1, 0.02), (5.2, 0.005), (5.2, 0.005), (5.3, 0.055), (5.3, 0.03), (5.4, 0.085), (5.4, 0.065), (5.5, 0.05), (5.5, 0.04), (5.6, 0.02), (5.6, 0.015), (5.7, 0.065), (5.7, 0.08), (5.8, 0.04), (5.8, 0.02), (5.9, 0.005), (5.9, 0.01), (6.0, 0.015), (6.0, 0.025), (6.1, 0.07), (6.1, 0.005), (6.2, 0.04), (6.2, 0.035), (6.3, 0.07), (6.3, 0.045), (6.4, 0.055), (6.4, 0.03), (6.5, 0.07), (6.5, 0.07), (6.6, 0.075), (6.6, 0.045), (6.7, 0.035), (6.7, 0.015), (6.8, 0.02), (6.8, 0.0), (6.9, 0.035), (6.9, 0.08), (7.0, 0.045), (7.0, 0.015), (7.1, 0.0), (7.1, 0.0), (7.2, 0.025), (7.2, 0.06), (7.3, 0.05), (7.3, 0.09), (7.4, 0.12), (7.4, 0.075), (7.5, 0.04), (7.5, 0.03), (7.6, 0.03), (7.6, 0.015), (7.7, 0.015), (7.7, 0.025), (7.8, 0.03), (7.8, 0.035), (7.9, 0.01), (7.9, 0.05), (8.0, 0.045), (8.0, 0.06), (8.1, 0.03), (8.1, 0.025), (8.2, 0.03), (8.2, 0.025), (8.3, 0.02), (8.3, 0.015), (8.4, 0.01), (8.4, 0.025), (8.5, 0.025), (8.5, 0.06), (8.6, 0.035), (8.6, 0.1), (8.7, 0.035), (8.7, 0.04), (8.8, 0.015), (8.8, 0.025), (8.9, 0.015), (8.9, 0.02), (9.0, 0.03), (9.0, 0.025), (9.1, 0.02), (9.1, 0.015), (9.2, 0.005), (9.2, 0.015), (9.3, 0.005), (9.3, 0.0), (9.4, 0.005), (9.4, 0.015), (9.5, 0.03), (9.5, 0.045), (9.6, 0.07), (9.6, 0.065), (9.7, 0.08), (9.7, 0.065), (9.8, 0.05), (9.8, 0.055), (9.9, 0.005), (9.9, 0.015), (10.0, 0.0), (10.0, 0.005), (10.1, 0.0), (10.1, 0.015), (10.2, 0.0), (10.2, 0.03), (10.3, 0.05), (10.3, 0.035), (10.4, 0.015), (10.4, 0.02), (10.5, 0.035), (10.5, 0.025), (10.6, 0.025), (10.6, 0.0), (10.7, 0.01), (10.7, 0.015), (10.8, 0.01), (10.8, 0.015), (10.9, 0.005), (10.9, 0.03), (11.0, 0.01), (11.0, 0.01), (11.1, 0.015), (11.1, 0.015), (11.2, 0.03), (11.2, 0.01), (11.3, 0.015), (11.3, 0.005), (11.4, 0.01), (11.4, 0.015), (11.5, 0.02), (11.5, 0.005), (11.6, 0.015), (11.6, 0.005), (11.7, 0.0), (11.7, 0.0), (11.8, 0.0), (11.8, 0.005), (11.9, 0.005), (11.9, 0.005)])

peaks, _ = find_peaks(info.T[1], height = 0.08)

# Define the exponential decay function
def exponential_decay(x, a, b):
    return a * np.exp(-b * x)

# Fit the exponential decay function to the data
popt, pcov = curve_fit(exponential_decay, info.T[0][peaks]-info.T[0][0], info.T[1][peaks])

# Get the fitted parameters
a_fit, b_fit = popt

# Generate points for the fitted curve
x_fit = np.linspace(info.T[0][peaks][0]-info.T[0][0], info.T[0][peaks][-1]-info.T[0][0], 100)
y_fit = exponential_decay(x_fit, a_fit, b_fit)
y_fit_chain13=exponential_decay(x_fit, a_fit, b_fit)
# Plot the original data and the fitted curve
plt.scatter(info.T[0]-info.T[0][0],info.T[1])
plt.scatter(info.T[0][peaks]-info.T[0][0], info.T[1][peaks], label='Peaks')
plt.plot(x_fit, y_fit, label='Exponential Fit', color='red')
plt.axvline((info.T[0][peaks]-info.T[0][0])[0], color = 'g', label='State Preparation Ends')
plt.xlabel('time, $\mu s$')
plt.ylabel(f"$|<Z_2|\Psi>|^2$")
plt.title('Exponential Decay Fit of 13-Atom Chain')
plt.legend()
plt.grid(True)
plt.savefig('chain13.png', dpi=500)
plt.show()

print("Fitted parameters:")
print("Initial Value =", a_fit)
print("Decay Rate =", b_fit)
pcov
# Out:
# Fitted parameters:
# Initial Value = 0.9233354810262578
# Decay Rate = 0.8603298360105096
# array([[0.01582701, 0.01539643],
#        [0.01539643, 0.02644466]])

# %%
#Chain9 with drive
info =np.array([(2.2, 0.84), (2.3, 0.87), (2.4, 0.88), (2.5, 0.61), (2.6, 0.14), (2.7, 0.0), (2.8, 0.0), (2.9, 0.02), (3.0, 0.06), (3.1, 0.04), (3.2, 0.02), (3.3, 0.02), (3.4, 0.02), (3.5, 0.01), (3.6, 0.0), (3.7, 0.01), (3.8, 0.19), (3.9, 0.34), (4.0, 0.43), (4.1, 0.34), (4.2, 0.37), (4.3, 0.33), (4.4, 0.24), (4.5, 0.16), (4.6, 0.08), (4.7, 0.03), (4.8, 0.01), (4.9, 0.01), (5.0, 0.0), (5.1, 0.0), (5.2, 0.0), (5.3, 0.0), (5.4, 0.0), (5.5, 0.01), (5.6, 0.03), (5.7, 0.02), (5.8, 0.04), (5.9, 0.22), (6.0, 0.35), (6.1, 0.43), (6.2, 0.38), (6.3, 0.41), (6.4, 0.33), (6.5, 0.15), (6.6, 0.04), (6.7, 0.01), (6.8, 0.01), (6.9, 0.05), (7.0, 0.07), (7.1, 0.07), (7.2, 0.08), (7.3, 0.07), (7.4, 0.07), (7.5, 0.02), (7.6, 0.04), (7.7, 0.03), (7.8, 0.16), (7.9, 0.32), (8.0, 0.4), (8.1, 0.41), (8.2, 0.47), (8.3, 0.47), (8.4, 0.36), (8.5, 0.1), (8.6, 0.01), (8.7, 0.02), (8.8, 0.03), (8.9, 0.02), (9.0, 0.04), (9.1, 0.04), (9.2, 0.04), (9.3, 0.04), (9.4, 0.04), (9.5, 0.01), (9.6, 0.01), (9.7, 0.12), (9.8, 0.36), (9.9, 0.53), (10.0, 0.58), (10.1, 0.57), (10.2, 0.52), (10.3, 0.39), (10.4, 0.12), (10.5, 0.0), (10.6, 0.0), (10.7, 0.03), (10.8, 0.02), (10.9, 0.05), (11.0, 0.03), (11.1, 0.04), (11.2, 0.04), (11.3, 0.03), (11.4, 0.01), (11.5, 0.0), (11.6, 0.03), (11.7, 0.13), (11.8, 0.18), (11.9, 0.18)])
peaks, _ = find_peaks(info.T[1], height = 0.1,distance=3)

# Define the exponential decay function
def exponential_decay(x, a, b):
    return a * np.exp(-b * x)

# Fit the exponential decay function to the data
popt, pcov = curve_fit(exponential_decay, info.T[0][peaks]-info.T[0][0], info.T[1][peaks])

# Get the fitted parameters
a_fit, b_fit = popt

# Generate points for the fitted curve
x_fit = np.linspace(info.T[0][peaks][0]-info.T[0][0], info.T[0][peaks][-1]-info.T[0][0], 100)
y_fit = exponential_decay(x_fit, a_fit, b_fit)
y_fit_chain9d=exponential_decay(x_fit, a_fit, b_fit)
# Plot the original data and the fitted curve
plt.scatter(info.T[0]-info.T[0][0],info.T[1])
plt.scatter(info.T[0][peaks]-info.T[0][0], info.T[1][peaks], label='Peaks')
plt.plot(x_fit, y_fit, label='Exponential Fit', color='red')
plt.axvline((info.T[0][peaks]-info.T[0][0])[0], color = 'g', label='State Preparation Ends')
plt.xlabel('time, $\mu s$')
plt.ylabel(f"$|<Z_2|\Psi>|^2$")
plt.title('Exponential Decay Fit of 9-Atom Chain (driven)')
plt.legend()
plt.grid(True)
plt.savefig('chain9d.png', dpi=500)
plt.show()

print("Fitted parameters:")
print("Initial Value =", a_fit)
print("Decay Rate =", b_fit)
pcov
# Out:
# Fitted parameters:
# Initial Value = 0.696974144170935
# Decay Rate = 0.060600176694041094
# array([[0.02644866, 0.00714081],
#        [0.00714081, 0.00335439]])

# %%
#square9 without drive
info =np.array([(2.2, 0.14), (2.3, 0.21), (2.4, 0.1), (2.5, 0.0), (2.6, 0.02), (2.7, 0.02), (2.8, 0.02), (2.9, 0.0), (3.0, 0.01), (3.1, 0.0), (3.2, 0.06), (3.3, 0.11), (3.4, 0.02), (3.5, 0.05), (3.6, 0.02), (3.7, 0.06), (3.8, 0.04), (3.9, 0.06), (4.0, 0.03), (4.1, 0.0), (4.2, 0.04), (4.3, 0.02), (4.4, 0.05), (4.5, 0.02), (4.6, 0.0), (4.7, 0.1), (4.8, 0.1), (4.9, 0.01), (5.0, 0.06), (5.1, 0.0), (5.2, 0.02), (5.3, 0.0), (5.4, 0.06), (5.5, 0.02), (5.6, 0.02), (5.7, 0.02), (5.8, 0.06), (5.9, 0.06), (6.0, 0.0), (6.1, 0.0), (6.2, 0.0), (6.3, 0.0), (6.4, 0.04), (6.5, 0.1), (6.6, 0.0), (6.7, 0.02), (6.8, 0.0), (6.9, 0.01), (7.0, 0.02), (7.1, 0.01), (7.2, 0.02), (7.3, 0.02), (7.4, 0.05), (7.5, 0.06), (7.6, 0.11), (7.7, 0.03), (7.8, 0.01), (7.9, 0.0), (8.0, 0.0), (8.1, 0.0), (8.2, 0.01), (8.3, 0.02), (8.4, 0.0), (8.5, 0.02), (8.6, 0.01), (8.7, 0.03), (8.8, 0.02), (8.9, 0.04)])
    
peaks, _ = find_peaks(info.T[1], height = 0.03,distance=9)

# Define the exponential decay function
def exponential_decay(x, a, b):
    return a * np.exp(-b * x)

# Fit the exponential decay function to the data
popt, pcov = curve_fit(exponential_decay, info.T[0][peaks]-info.T[0][0], info.T[1][peaks])

# Get the fitted parameters
a_fit, b_fit = popt

# Generate points for the fitted curve
x_fit = np.linspace(info.T[0][peaks][0]-info.T[0][0], info.T[0][peaks][-1]-info.T[0][0], 100)
y_fit = exponential_decay(x_fit, a_fit, b_fit)
y_fit_square9=exponential_decay(x_fit, a_fit, b_fit)
# Plot the original data and the fitted curve
plt.scatter(info.T[0]-info.T[0][0],info.T[1])
plt.scatter(info.T[0][peaks]-info.T[0][0], info.T[1][peaks], label='Peaks')
plt.plot(x_fit, y_fit, label='Exponential Fit', color='red')
plt.axvline((info.T[0][peaks]-info.T[0][0])[0], color = 'g', label='State Preparation Ends')
plt.xlabel('time, $\mu s$')
plt.ylabel(f"$|<Z_2|\Psi>|^2$")
plt.title('Exponential Decay Fit of 9-Atom Square')
plt.legend()
plt.grid(True)
plt.savefig('square9.png', dpi=500)
plt.show()

print("Fitted parameters:")
print("Initial Value =", a_fit)
print("Decay Rate =", b_fit)
# Out:
# Fitted parameters:
# Initial Value = 0.18328247885715526
# Decay Rate = 0.18030939192666415

# %%
#square9 without drive
info =np.array([(2.2, 0.18), (2.3, 0.2), (2.4, 0.12), (2.5, 0.09), (2.6, 0.03), (2.7, 0.0), (2.8, 0.0), (2.9, 0.02), (3.0, 0.01), (3.1, 0.0), (3.2, 0.0), (3.3, 0.0), (3.4, 0.0), (3.5, 0.04), (3.6, 0.0), (3.7, 0.0), (3.8, 0.0), (3.9, 0.0), (4.0, 0.04), (4.1, 0.02), (4.2, 0.04), (4.3, 0.02), (4.4, 0.04), (4.5, 0.08), (4.6, 0.02), (4.7, 0.0), (4.8, 0.02), (4.9, 0.02), (5.0, 0.01), (5.1, 0.0), (5.2, 0.0), (5.3, 0.0), (5.4, 0.0), (5.5, 0.03), (5.6, 0.0), (5.7, 0.0), (5.8, 0.0), (5.9, 0.0), (6.0, 0.02), (6.1, 0.04), (6.2, 0.04), (6.3, 0.05), (6.4, 0.04), (6.5, 0.02), (6.6, 0.01), (6.7, 0.01), (6.8, 0.0), (6.9, 0.04), (7.0, 0.01), (7.1, 0.02), (7.2, 0.02), (7.3, 0.0), (7.4, 0.02), (7.5, 0.02), (7.6, 0.02), (7.7, 0.01), (7.8, 0.0), (7.9, 0.04), (8.0, 0.03), (8.1, 0.02), (8.2, 0.02), (8.3, 0.02), (8.4, 0.02), (8.5, 0.0), (8.6, 0.01), (8.7, 0.01), (8.8, 0.0), (8.9, 0.0)])
peaks, _ = find_peaks(info.T[1], height = 0.03,distance=9)

# Define the exponential decay function
def exponential_decay(x, a, b):
    return a * np.exp(-b * x)

# Fit the exponential decay function to the data
popt, pcov = curve_fit(exponential_decay, info.T[0][peaks]-info.T[0][0], info.T[1][peaks])

# Get the fitted parameters
a_fit, b_fit = popt

# Generate points for the fitted curve
x_fit = np.linspace(info.T[0][peaks][0]-info.T[0][0], info.T[0][peaks][-1]-info.T[0][0], 100)
y_fit = exponential_decay(x_fit, a_fit, b_fit)
y_fit_square9d=exponential_decay(x_fit, a_fit, b_fit)
# Plot the original data and the fitted curve
plt.scatter(info.T[0]-info.T[0][0],info.T[1])
plt.scatter(info.T[0][peaks]-info.T[0][0], info.T[1][peaks], label='Peaks')
plt.plot(x_fit, y_fit, label='Exponential Fit', color='red')
plt.axvline((info.T[0][peaks]-info.T[0][0])[0], color = 'g', label='State Preparation Ends')
plt.xlabel('time, $\mu s$')
plt.ylabel(f"$|<Z_2|\Psi>|^2$")
plt.title('Exponential Decay Fit of 9-Atom Square (driven)')
plt.legend()
plt.grid(True)
plt.savefig('Squared.png', dpi=500)
plt.show()

print("Fitted parameters:")
print("Initial Value =", a_fit)
print("Decay Rate =", b_fit)
# Out:
# Fitted parameters:
# Initial Value = 0.18906712194062192
# Decay Rate = 0.5007933626857672

# %%
#circle10 without drive
info =np.array([(2.2, 0.18), (2.3, 0.18), (2.4, 0.13), (2.5, 0.0), (2.6, 0.03), (2.7, 0.06), (2.8, 0.0), (2.9, 0.03), (3.0, 0.01), (3.1, 0.0), (3.2, 0.0), (3.3, 0.02), (3.4, 0.02), (3.5, 0.01), (3.6, 0.02), (3.7, 0.04), (3.8, 0.01), (3.9, 0.01), (4.0, 0.03), (4.1, 0.0), (4.2, 0.0), (4.3, 0.01), (4.4, 0.0), (4.5, 0.0), (4.6, 0.0), (4.7, 0.03), (4.8, 0.0), (4.9, 0.01), (5.0, 0.03), (5.1, 0.01), (5.2, 0.0), (5.3, 0.01), (5.4, 0.02), (5.5, 0.0), (5.6, 0.0), (5.7, 0.01), (5.8, 0.02), (5.9, 0.0), (6.0, 0.0), (6.1, 0.0), (6.2, 0.02), (6.3, 0.01), (6.4, 0.02), (6.5, 0.01), (6.6, 0.0), (6.7, 0.0), (6.8, 0.01), (6.9, 0.0), (7.0, 0.01), (7.1, 0.01), (7.2, 0.01), (7.3, 0.01), (7.4, 0.01), (7.5, 0.0), (7.6, 0.01), (7.7, 0.0), (7.8, 0.01), (7.9, 0.0), (8.0, 0.0), (8.1, 0.0), (8.2, 0.01), (8.3, 0.01), (8.4, 0.02), (8.5, 0.01), (8.6, 0.0), (8.7, 0.0), (8.8, 0.0), (8.9, 0.01), (9.0, 0.0), (9.1, 0.01), (9.2, 0.0), (9.3, 0.0), (9.4, 0.0), (9.5, 0.0), (9.6, 0.0), (9.7, 0.01), (9.8, 0.01), (9.9, 0.0), (10.0, 0.0), (10.1, 0.01), (10.2, 0.01), (10.3, 0.0), (10.4, 0.0), (10.5, 0.0), (10.6, 0.0), (10.7, 0.0), (10.8, 0.0), (10.9, 0.0), (11.0, 0.0), (11.1, 0.0), (11.2, 0.0), (11.3, 0.0), (11.4, 0.0), (11.5, 0.0), (11.6, 0.0), (11.7, 0.0), (11.8, 0.0), (11.9, 0.0)])

peaks, _ = find_peaks(info.T[1], height = 0.01,distance=8)

# Define the exponential decay function
def exponential_decay(x, a, b):
    return a * np.exp(-b * x)

# Fit the exponential decay function to the data
popt, pcov = curve_fit(exponential_decay, info.T[0][peaks]-info.T[0][0], info.T[1][peaks])

# Get the fitted parameters
a_fit, b_fit = popt

# Generate points for the fitted curve
x_fit = np.linspace(info.T[0][peaks][0]-info.T[0][0], info.T[0][peaks][-1]-info.T[0][0], 100)
y_fit = exponential_decay(x_fit, a_fit, b_fit)
y_fit_circle10=exponential_decay(x_fit, a_fit, b_fit)
# Plot the original data and the fitted curve
plt.scatter(info.T[0]-info.T[0][0],info.T[1])
plt.scatter(info.T[0][peaks]-info.T[0][0], info.T[1][peaks], label='Peaks')
plt.plot(x_fit, y_fit, label='Exponential Fit', color='red')
plt.axvline((info.T[0][peaks]-info.T[0][0])[0], color = 'g', label='State Preparation Ends')
plt.xlabel('time, $\mu s$')
plt.ylabel(f"$|<Z_2|\Psi>|^2$")
plt.title('Exponential Decay Fit of 10-Atom Circle')
plt.legend()
plt.grid(True)

plt.savefig('circle.png', dpi=500)
plt.show()

print("Fitted parameters:")
print("Initial Value =", a_fit)
print("Decay Rate =", b_fit)
# Out:
# Fitted parameters:
# Initial Value = 0.06760915495067119
# Decay Rate = 0.31694042089885044

# %%
#circle10 with drive
info =np.array([(2.2, 0.16), (2.3, 0.15), (2.4, 0.21), (2.5, 0.18), (2.6, 0.05), (2.7, 0.0), (2.8, 0.0), (2.9, 0.01), (3.0, 0.06), (3.1, 0.07), (3.2, 0.06), (3.3, 0.05), (3.4, 0.07), (3.5, 0.04), (3.6, 0.02), (3.7, 0.0), (3.8, 0.0), (3.9, 0.0), (4.0, 0.03), (4.1, 0.03), (4.2, 0.03), (4.3, 0.03), (4.4, 0.07), (4.5, 0.04), (4.6, 0.01), (4.7, 0.0), (4.8, 0.0), (4.9, 0.0), (5.0, 0.01), (5.1, 0.0), (5.2, 0.0), (5.3, 0.0), (5.4, 0.01), (5.5, 0.01), (5.6, 0.0), (5.7, 0.0), (5.8, 0.01), (5.9, 0.03), (6.0, 0.02), (6.1, 0.01), (6.2, 0.01), (6.3, 0.01), (6.4, 0.01), (6.5, 0.0), (6.6, 0.0), (6.7, 0.0), (6.8, 0.01), (6.9, 0.0), (7.0, 0.0), (7.1, 0.0), (7.2, 0.0), (7.3, 0.0), (7.4, 0.01), (7.5, 0.0), (7.6, 0.0), (7.7, 0.01), (7.8, 0.0), (7.9, 0.0), (8.0, 0.0), (8.1, 0.0), (8.2, 0.0), (8.3, 0.0), (8.4, 0.01), (8.5, 0.01), (8.6, 0.0), (8.7, 0.0), (8.8, 0.0), (8.9, 0.01), (9.0, 0.01), (9.1, 0.01), (9.2, 0.01), (9.3, 0.0), (9.4, 0.0), (9.5, 0.0), (9.6, 0.0), (9.7, 0.0), (9.8, 0.0), (9.9, 0.0), (10.0, 0.0), (10.1, 0.0), (10.2, 0.0), (10.3, 0.0), (10.4, 0.01), (10.5, 0.0), (10.6, 0.01), (10.7, 0.01), (10.8, 0.0), (10.9, 0.0), (11.0, 0.01), (11.1, 0.01), (11.2, 0.01), (11.3, 0.01), (11.4, 0.01), (11.5, 0.01), (11.6, 0.0), (11.7, 0.01), (11.8, 0.0), (11.9, 0.0)])

peaks, _ = find_peaks(info.T[1], height = 0.01,distance=9)

# Define the exponential decay function
def exponential_decay(x, a, b):
    return a * np.exp(-b * x)

# Fit the exponential decay function to the data
popt, pcov = curve_fit(exponential_decay, info.T[0][peaks]-info.T[0][0], info.T[1][peaks])

# Get the fitted parameters
a_fit, b_fit = popt

# Generate points for the fitted curve
x_fit = np.linspace(info.T[0][peaks][0]-info.T[0][0], info.T[0][peaks][-1]-info.T[0][0], 100)
y_fit = exponential_decay(x_fit, a_fit, b_fit)
y_fit_circle10d=exponential_decay(x_fit, a_fit, b_fit)
# Plot the original data and the fitted curve
plt.scatter(info.T[0]-info.T[0][0],info.T[1])
plt.scatter(info.T[0][peaks]-info.T[0][0], info.T[1][peaks], label='Peaks')
plt.plot(x_fit, y_fit, label='Exponential Fit', color='red')
plt.axvline((info.T[0][peaks]-info.T[0][0])[0], color = 'g', label='State Preparation Ends')
plt.xlabel('time, $\mu s$')
plt.ylabel(f"$|<Z_2|\Psi>|^2$")
plt.title('Exponential Decay Fit of 10-Atom Circle (driven)')
plt.legend()
plt.grid(True)
plt.savefig('circled.png', dpi=500)
plt.show()

print("Fitted parameters:")
print("Initial Value =", a_fit)
print("Decay Rate =", b_fit)
# Out:
# Fitted parameters:
# Initial Value = 0.2307819476560042
# Decay Rate = 0.6919261608435867

# %%
#hc10 without drive
info =np.array([(2.2, 0.49), (2.3, 0.55), (2.4, 0.42), (2.5, 0.0), (2.6, 0.12), (2.7, 0.26), (2.8, 0.0), (2.9, 0.14), (3.0, 0.1), (3.1, 0.06), (3.2, 0.1), (3.3, 0.18), (3.4, 0.07), (3.5, 0.18), (3.6, 0.04), (3.7, 0.01), (3.8, 0.32), (3.9, 0.14), (4.0, 0.02), (4.1, 0.18), (4.2, 0.29), (4.3, 0.04), (4.4, 0.06), (4.5, 0.08), (4.6, 0.12), (4.7, 0.04), (4.8, 0.02), (4.9, 0.17), (5.0, 0.01), (5.1, 0.12), (5.2, 0.18), (5.3, 0.08), (5.4, 0.06), (5.5, 0.35), (5.6, 0.12), (5.7, 0.08), (5.8, 0.02), (5.9, 0.2), (6.0, 0.22), (6.1, 0.02), (6.2, 0.0), (6.3, 0.0), (6.4, 0.24), (6.5, 0.26), (6.6, 0.01), (6.7, 0.02), (6.8, 0.0), (6.9, 0.16), (7.0, 0.08), (7.1, 0.02), (7.2, 0.02), (7.3, 0.04), (7.4, 0.11), (7.5, 0.12), (7.6, 0.08), (7.7, 0.1), (7.8, 0.17), (7.9, 0.34), (8.0, 0.26), (8.1, 0.02), (8.2, 0.0), (8.3, 0.06), (8.4, 0.03), (8.5, 0.08), (8.6, 0.18), (8.7, 0.12), (8.8, 0.07), (8.9, 0.02), (9.0, 0.05), (9.1, 0.02), (9.2, 0.02), (9.3, 0.04), (9.4, 0.06), (9.5, 0.09), (9.6, 0.09), (9.7, 0.06), (9.8, 0.04), (9.9, 0.17), (10.0, 0.12), (10.1, 0.14), (10.2, 0.08), (10.3, 0.06), (10.4, 0.04), (10.5, 0.04), (10.6, 0.02), (10.7, 0.02), (10.8, 0.04), (10.9, 0.04)])
peaks, _ = find_peaks(info.T[1], height = 0.1,distance=9)

# Define the exponential decay function
def exponential_decay(x, a, b):
    return a * np.exp(-b * x)

# Fit the exponential decay function to the data
popt, pcov = curve_fit(exponential_decay, info.T[0][peaks]-info.T[0][0], info.T[1][peaks])

# Get the fitted parameters
a_fit, b_fit = popt

# Generate points for the fitted curve
x_fit = np.linspace(info.T[0][peaks][0]-info.T[0][0], info.T[0][peaks][-1]-info.T[0][0], 100)
y_fit = exponential_decay(x_fit, a_fit, b_fit)
y_fit_hc10=exponential_decay(x_fit, a_fit, b_fit)
# Plot the original data and the fitted curve
plt.scatter(info.T[0]-info.T[0][0],info.T[1])
plt.scatter(info.T[0][peaks]-info.T[0][0], info.T[1][peaks], label='Peaks')
plt.plot(x_fit, y_fit, label='Exponential Fit', color='red')
plt.axvline((info.T[0][peaks]-info.T[0][0])[0], color = 'g', label='State Preparation Ends')
plt.xlabel('time, $\mu s$')
plt.ylabel(f"$|<Z_2|\Psi>|^2$")
plt.title('Exponential Decay Fit of 10-Atom HoneyComb')
plt.legend()
plt.grid(True)
plt.savefig('hc.png', dpi=500)
plt.show()

print("Fitted parameters:")
print("Initial Value =", a_fit)
print("Decay Rate =", b_fit)
# Out:
# Fitted parameters:
# Initial Value = 0.5019497041235589
# Decay Rate = 0.12224052617703825

# %%
#hc10 with drive
info =np.array([(2.2, 0.5), (2.3, 0.49), (2.4, 0.56), (2.5, 0.54), (2.6, 0.17), (2.7, 0.04), (2.8, 0.0), (2.9, 0.14), (3.0, 0.37), (3.1, 0.42), (3.2, 0.3), (3.3, 0.33), (3.4, 0.3), (3.5, 0.12), (3.6, 0.14), (3.7, 0.15), (3.8, 0.1), (3.9, 0.19), (4.0, 0.14), (4.1, 0.1), (4.2, 0.1), (4.3, 0.08), (4.4, 0.18), (4.5, 0.15), (4.6, 0.02), (4.7, 0.18), (4.8, 0.08), (4.9, 0.01), (5.0, 0.02), (5.1, 0.05), (5.2, 0.06), (5.3, 0.09), (5.4, 0.16), (5.5, 0.16), (5.6, 0.09), (5.7, 0.02), (5.8, 0.04), (5.9, 0.0), (6.0, 0.02), (6.1, 0.02), (6.2, 0.04), (6.3, 0.07), (6.4, 0.04), (6.5, 0.03), (6.6, 0.07), (6.7, 0.0), (6.8, 0.08), (6.9, 0.15), (7.0, 0.06), (7.1, 0.1), (7.2, 0.06), (7.3, 0.04), (7.4, 0.04), (7.5, 0.03), (7.6, 0.12), (7.7, 0.08), (7.8, 0.08), (7.9, 0.08), (8.0, 0.1), (8.1, 0.12), (8.2, 0.08), (8.3, 0.06), (8.4, 0.02), (8.5, 0.0), (8.6, 0.06), (8.7, 0.08), (8.8, 0.1), (8.9, 0.12), (9.0, 0.11), (9.1, 0.16), (9.2, 0.15), (9.3, 0.16), (9.4, 0.17), (9.5, 0.06), (9.6, 0.04), (9.7, 0.02), (9.8, 0.13), (9.9, 0.16), (10.0, 0.12), (10.1, 0.16), (10.2, 0.15), (10.3, 0.16), (10.4, 0.1), (10.5, 0.1), (10.6, 0.06), (10.7, 0.08), (10.8, 0.12), (10.9, 0.1)])

peaks, _ = find_peaks(info.T[1], height = 0.1,distance=6)

# Define the exponential decay function
def exponential_decay(x, a, b):
    return a * np.exp(-b * x)

# Fit the exponential decay function to the data
popt, pcov = curve_fit(exponential_decay, info.T[0][peaks]-info.T[0][0], info.T[1][peaks])

# Get the fitted parameters
a_fit, b_fit = popt

# Generate points for the fitted curve
x_fit = np.linspace(info.T[0][peaks][0]-info.T[0][0], info.T[0][peaks][-1]-info.T[0][0], 100)
y_fit = exponential_decay(x_fit, a_fit, b_fit)
y_fit_hc10d=exponential_decay(x_fit, a_fit, b_fit)
# Plot the original data and the fitted curve
plt.scatter(info.T[0]-info.T[0][0],info.T[1])
plt.scatter(info.T[0][peaks]-info.T[0][0], info.T[1][peaks], label='Peaks')
plt.plot(x_fit, y_fit, label='Exponential Fit', color='red')
plt.axvline((info.T[0][peaks]-info.T[0][0])[0], color = 'g', label='State Preparation Ends')
plt.xlabel('time, $\mu s$')
plt.ylabel(f"$|<Z_2|\Psi>|^2$")
plt.title('Exponential Decay Fit of 10-Atom HoneyComb (driven)')
plt.legend()
plt.grid(True)
plt.savefig('hcd.png', dpi=500)
plt.show()

print("Fitted parameters:")
print("Initial Value =", a_fit)
print("Decay Rate =", b_fit)
# Out:
# Fitted parameters:
# Initial Value = 0.49670001902106775
# Decay Rate = 0.2647999982819217

# %%
plt.plot(x_fit,y_fit_chain13,label="13-Atom Chain")
plt.plot(x_fit,y_fit_chain9d,label="9-Atom Chain (driven)",ls='--')
plt.plot(x_fit,y_fit_square9,label="9-Atom Square")
plt.plot(x_fit,y_fit_square9d,label="9-Atom Square (drive)",ls='--')
plt.plot(x_fit,y_fit_circle10,label="10-Atom Circle")
plt.plot(x_fit,y_fit_circle10d,label="10-Atom Circle (driven)",ls='--')
plt.plot(x_fit,y_fit_hc10,label="10-Atom HoneyComb")
plt.plot(x_fit,y_fit_hc10d,label="10-Atom HoneyComb (driven)",ls='--')
plt.xlabel('time, $\mu s$')
plt.ylabel(f"$|<Z_2|\Psi>|^2$")
plt.title('Exponential Decay Fit Comparison')
plt.legend()
plt.grid(True)
plt.savefig('exponentialcomp.png', dpi=500)
plt.show()
